# %%
from PyPDF2 import PdfReader
import os

# %%
# Define the path to the uploads folder
uploads_dir = os.path.join('..', 'uploads')  # Adjust path if needed based on the notebook's location
pdf_file = 'tcs.pdf'
pdf_path = os.path.join(uploads_dir, pdf_file)
pdf_path
# Out:
# '..\\uploads\\tcs.pdf'

# %%
reader = PdfReader(pdf_path)

## extrat whole text
corpus = ""
for page in reader.pages:
     corpus+=page.extract_text()

# %% [markdown]
# now we have full text of particular pdf in "corpus" variable

# %% [markdown]
# ### Preprocessing

# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 678.7 kB/s eta 0:00:00
# Requirement already satisfied: click in d:\data-science\projects\financial_analyst_assistant_portal\.myenv\lib\site-packages (from nltk) (8.1.7)
# Collecting joblib
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      ------------------------------------ 301.8/301.8 kB 405.5 kB/s eta 0:00:00
# Collecting regex>=2021.8.3
#   Downloading regex-2024.9.11-cp311-cp311-win_amd64.whl (274 kB)
#      ------------------------------------ 274.0/274.0 kB 367.4 kB/s eta 0:00:00
# Collecting tqdm
#   Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Requirement already satisfied: colorama in d:\data-science\projects\financial_analyst_assistant_portal\.myenv\lib\site-packages (from click->nltk) (0.4.6)
# Installing collected packages: tqdm, regex, joblib, nltk
# Successfully installed joblib-1.4.2 nltk-3.9.1 regex-2024.9.11 tqdm-4.66.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import re
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

# %%
text = re.sub('[^a-zA-Z0-9]',' ', corpus)
text.lower()
text = word_tokenize(pattern)

lemmatizer = WordNetLemmatizer()
lemmatized_text = [lemmatizer.lemmatize(t) for t in text if t not in stopwords.words('english') ]
lemmatized_text = ' '.join(lemmatized_text)

# %% [markdown]
# #### We have text after punctuation remove, lemmatization and stopwords.

# %%
lemmatized_text
# Out:
# 'Integrated A caltnnual Report 20 year value creation 2004 2024 2023 2024 2 TRANSFORMING INDUSTRIES Integrated Annual Report 2023 2024 20 year creating value Since IPO 2004 2 TRANSFORMING INDUSTRIES Backdrop TCS Gitanjali Park Campus Kolkata IndiaTata Consultancy Services IT service consulting business solution organization partnering many world largest business transformation journey 56 year Its consulting led cognitive powered portfolio business technology engineering service solution delivered unique Location Independent Agile delivery model recognized benchmark excellence software development A part Tata group India largest multinational business group TCS 601 000 world best trained consultant 54 country The company generated consolidated revenue US 29 1 billion fiscal year ended March 31 2024 listed BSE NSE India TCS proactive stance climate change award winning work community across world earned place leading sustainability index MSCI Global Sustainability Index FTSE4Good Emerging Index For information visit www tc comAbout TCS Transforming Industries The TCS FY 2023 24 FY 2024 Integrated Annual Report delf capability technological innovation impact business model Technology increasingly enabler enterprise adapt thrive new era Businesses relying technology help improve competitive advantage drive strategy growth From Banking Retail Manufacturing Healthcare Utilities technology Transforming Industries way operate enhance customer employee experience TCS full service capability industry specific contextual knowledge always remained relevant client stayed close past technology cycle The synergistic relationship Cloud AI GenAI technology ushering significant shift industry approach innovation efficiency With half workforce trained AI ML Gen AI TCS continue client trusted transformation partner Recent Annual Report Themes FY 2023 Innovate Adapt ThriveInnovating Greater FuturesFY 2022 Building BeliefFY 2021 FY 2020 Purpos e driven Resilient Adapt able Growth Transformation Business 4 0TMFY 2019 About TCS Board Directors Management Team Letter Chairman Letter CEO The Year Gone 173180181182184 186 241 250251252254 256 304 315 318325307 35 55699193117127Statutory Section Notice Directors Report Management Discussion Analysis Awards Accolades Corporate Governance Report Corporate Social Responsibility Business Responsibility Sustainability Report Thematic SectionIntegrated Reporting Framework Standalone Financial Statements Independent Auditor Report Standalone Balance Sheet Standalone Statement Profit Loss Standalone Statement Changes Equity Standalone Statement Cash Flows Notes forming part Standalone Financial Statements Statement section 129 Companies Act 2013 relating Subsidiary Companies Stakeholder Engagement Identification Material Topics Climate Related Disclosures GRI Content Index Sustainability DisclosuresGlossary Independent Auditor Report Consolidated Balance Sheet Consolidated Statement Profit Loss Consolidated Statement Changes Equity Consolidated Statement Cash Flows Notes forming part Consolidated Financial Statements Consolidated Financial Statements Trading old new SIX unveils advanced post trading platform Shaping future accessibility financial inclusion Connecting India Faster BSNL 4G 5G Network roll A joint venture give rise digitally powered insurance firm AI Business Study Disrupting Industry Boundaries Transactions Interactions AI GenAI Stories 262728 29 30 32 33 Content 020405060811 15 1618202224TCS Integrated Business Model Financial Capital Human Capital Intellectual Capital Social Capital Natural Capital Content 3 Integrated Annual Report 2023 24Board Directors Aarthi Subramanian M N Keki Mistry CCM I N Chandrasekaran Chairman CCM N Hanne Sorensen MM I Al Noor Ramji MM I C MM IO P Bhatt Dr Pradeep Kumar Khosla CM I K Krithivasan CEO MD MMMNE N G Subramaniam COO ED MMNE Non Independent Non Executive Non Independent Executive Independent Non Executive C M Board Committ ee Chairman Member Executive Commi ...

# %% [markdown]
# ### Word2Vec

# %%
import gensim
from gensim.models import Word2Vec
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 import gensim
#       2 from gensim.models import Word2Vec
#
# ModuleNotFoundError: No module named 'gensim'

# %%
model=Word2Vec(words,window=5,min_count=2)

# %%
model.wv.index_to_key

# %%
model.corpus_count

# %%
model.epochs

# %%
model.wv.similar_by_word('kid')

# %%
model.wv['kid'].shape
